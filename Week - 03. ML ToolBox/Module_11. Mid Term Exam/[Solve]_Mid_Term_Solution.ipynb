# %% [markdown]
# #               Mid Term Answer Script
# #### registered email address : *******@gmail.com

# %% [markdown]
# 0) Starter Code

# %%
import numpy as np
import pandas as pd

np.random.seed(24)

num_employees = 50  # you can increase this if needed

# Employee data
emp_ids = np.arange(101, 101 + num_employees)
emp_ages = np.random.randint(20, 55, num_employees)
emp_income = np.random.randint(35000, 95000, num_employees)

# Fixed set of roles (repetition allowed)
roles_list = [
    "HR Manager",
    "Software Developer",
    "Accountant",
    "Marketing Executive",
    "Sales Executive",
    "Backend Developer",
    "HR Executive",
    "Financial Analyst",
    "Digital Marketer",
    "Operations Manager"
]

emp_roles = np.random.choice(roles_list, num_employees)

# Create DataFrame
data = pd.DataFrame({
    "emp_id": emp_ids,
    "emp_age": emp_ages,
    "emp_salary": emp_income,
    "role": emp_roles
})

# Save dataset
data.to_csv("staff_data.csv", index=False)

# %% [markdown]
# # 1) NumPy — 5 Questions

# %% [markdown]
# ### Q1.
# Use  NumPy arrays from the emp_ages and emp_salary columns. Print both arrays and display:
# * data type
# * number of dimensions
# * shape
# * total number of elements

# %%
# Q1 Solution :

emp_ages = np.array(data['emp_age'])
emp_salary = np.array(data['emp_salary'])

print(emp_ages)
print(emp_ages.dtype)
print(emp_ages.ndim)
print(emp_ages.shape)
print(emp_ages.size)
print()


print(emp_salary)
print(emp_salary.dtype)
print(emp_salary.ndim)
print(emp_salary.shape)
print(emp_salary.size)
print()
# Out:
# [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# int64
# 1
# (50,)
# 50
#
# [51725 38495 35452 82295 72187 58915 76159 92864 76155 90494 68641 48079
#  56879 83682 94722 91041 48899 68744 63187 74146 75641 47678 76760 78354
#  60584 79898 59682 71888 51086 73700 82550 71447 76100 72269 73314 87428
#  94427 84188 52013 63326 44396 59500 55523 58602 90794 41061 82331 73048
#  59727 50398]
# int64
# 1
# (50,)
# 50

# %% [markdown]
# ### Q2.
# Using NumPy functions:
# * Find the maximum and minimum salary
# * Calculate the average salary
# * Calculate the average age
# * Print all results.

# %%
max_sal = np.max(emp_salary)
min_sal = np.min(emp_salary)
average_sal = np.average(emp_salary)
average_age = np.average(emp_ages)

print("Max Salary:", max_sal)
print("Min Salary:", min_sal)
print("Average Salary:", average_sal)
print("Average Age:", average_age)
# Out:
# Max Salary: 94722
# Min Salary: 35452
# Average Salary: 68409.48
# Average Age: 35.44

# %% [markdown]
# ### Q3.
# From the emp_ages array: Extract employees who:
# * are aged between 25 and 40, AND Emp_salary : have salary greater than 50,000
# * Then : Print the filtered values Count how many employees satisfy this condition

# %%
employee_2540_50k = emp_ages[ ( (emp_ages >= 25) & (emp_ages <= 40) ) & (emp_salary > 50000)]
print(employee_2540_50k)
print(len(employee_2540_50k))
# Out:
# [37 37 35 38 31 29 38 27 32 26 37 26 30 30 27 25 31]
# 17

# %% [markdown]
# ### Q4.
# Create a new NumPy array where each employee’s age is adjusted based on:
# * Add 4 years if age is less than the average age
# * Add 2 years if age is greater than or equal to the average age
#
# Do NOT modify the original array.
#
# * Print original array
# * updated array
# * average age used for condition

# %%
new_emp_ages = np.where( emp_ages < average_age, emp_ages+4, emp_ages+2)

print("Original Array: ", emp_ages)
print("Updated Array:", new_emp_ages)
print("Average Age:", average_age)
# Out:
# Original Array:  [54 23 20 43 37 37 21 35 24 38 31 35 29 38 27 45 51 48 20 32 51 53 21 26
#  53 37 26 21 45 30 20 47 53 53 23 24 21 30 27 25 39 20 47 41 22 52 42 54
#  31 50]
# Updated Array: [56 27 24 45 39 39 25 39 28 40 35 39 33 40 31 47 53 50 24 36 53 55 25 30
#  55 39 30 25 47 34 24 49 55 55 27 28 25 34 31 29 41 24 49 43 26 54 44 56
#  35 52]
# Average Age: 35.44

# %% [markdown]
# ### Q5.
# Using NumPy:
# * Assume all salaries of Tech roles increase by 8%
# * Calculate the new total salary expense
# * Find the overall increase in expense after the raise
#
# **Print both old and new totals along with the difference.**

# %%
salary_exp = np.sum(emp_salary)

tech_rols = ['Backend Developer', 'Software Developer']
tech_rol_sal = np.where( data['role'].isin(tech_rols), emp_salary*1.08, emp_salary)

new_total = np.sum(tech_rol_sal)


print("Old Total: ", salary_exp)
print("New Total: ", new_total)
print("Difference: ", new_total - salary_exp)
# Out:
# Old Total:  3420474
# New Total:  3490246.0
# Difference:  69772.0

# %% [markdown]
# # 2) Pandas — 5 Questions

# %% [markdown]
# ### Q6.
#  Load the staff_data.csv file into a Pandas DataFrame.
# * Display the first 3 rows
# * Show dataset information using .info()
# * Display summary statistics using .describe()

# %%
df = pd.read_csv('staff_data.csv')
df.head(3)
# Out:
#    emp_id  emp_age  emp_salary                role
# 0     101       54       51725          HR Manager
# 1     102       23       38495          Accountant
# 2     103       20       35452  Operations Manager

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     int64
#  1   emp_age     50 non-null     int64
#  2   emp_salary  50 non-null     int64
#  3   role        50 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#           emp_id    emp_age    emp_salary
# count   50.00000  50.000000     50.000000
# mean   125.50000  35.440000  68409.480000
# std     14.57738  11.768446  15727.122334
# min    101.00000  20.000000  35452.000000
# 25%    113.25000  24.250000  57309.750000
# 50%    125.50000  35.000000  72037.500000
# 75%    137.75000  46.500000  79512.000000
# max    150.00000  54.000000  94722.000000

# %% [markdown]
# ### Q7.
# Filter the dataset to include only:
# * emp_id, emp_age, role
#
# Then:
# * Select employees whose age is between 25 and 40
# * Sort them by emp_id
# * Display the last 3 rows of the result

# %%
df_new = df[['emp_id', 'emp_age', 'role']]
df_new
# Out:
#     emp_id  emp_age                 role
# 0      101       54           HR Manager
# 1      102       23           Accountant
# 2      103       20   Operations Manager
# 3      104       43     Digital Marketer
# 4      105       37    Backend Developer
# 5      106       37           HR Manager
# 6      107       21    Backend Developer
# 7      108       35      Sales Executive
# 8      109       24      Sales Executive
# 9      110       38         HR Executive
# 10     111       31    Backend Developer
# 11     112       35  Marketing Executive
# 12     113       29      Sales Executive
# 13     114       38   Operations Manager
# 14     115       27     Digital Marketer
# 15     116       45    Financial Analyst
# 16     117       51      Sales Executive
# 17     118       48   Operations Manager
# 18     119       20   Software Developer
# 19     120       32    Backend Developer
# 20     121       51      Sales Executive
# 21     122       53      Sales Executive
# ...

# %%
df_new_2540 = df_new[ ( (df_new['emp_age'] >= 25) & (df_new['emp_age'] <= 40) ) ]
df_new_2540
# Out:
#     emp_id  emp_age                 role
# 4      105       37    Backend Developer
# 5      106       37           HR Manager
# 7      108       35      Sales Executive
# 9      110       38         HR Executive
# 10     111       31    Backend Developer
# 11     112       35  Marketing Executive
# 12     113       29      Sales Executive
# 13     114       38   Operations Manager
# 14     115       27     Digital Marketer
# 19     120       32    Backend Developer
# 23     124       26   Software Developer
# 25     126       37   Operations Manager
# 26     127       26     Digital Marketer
# 29     130       30           Accountant
# 37     138       30           Accountant
# 38     139       27           HR Manager
# 39     140       25      Sales Executive
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer

# %%
df_new_2540.sort_values('emp_id', ascending=True)
df_new_2540
# Out:
#     emp_id  emp_age                 role
# 4      105       37    Backend Developer
# 5      106       37           HR Manager
# 7      108       35      Sales Executive
# 9      110       38         HR Executive
# 10     111       31    Backend Developer
# 11     112       35  Marketing Executive
# 12     113       29      Sales Executive
# 13     114       38   Operations Manager
# 14     115       27     Digital Marketer
# 19     120       32    Backend Developer
# 23     124       26   Software Developer
# 25     126       37   Operations Manager
# 26     127       26     Digital Marketer
# 29     130       30           Accountant
# 37     138       30           Accountant
# 38     139       27           HR Manager
# 39     140       25      Sales Executive
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer

# %%
df_new_2540.tail(3)
# Out:
#     emp_id  emp_age                 role
# 39     140       25      Sales Executive
# 40     141       39  Marketing Executive
# 48     149       31     Digital Marketer

# %% [markdown]
# ### Q8.
# Filter the DataFrame to show only employees working in the "HR" role.
# * Print the filtered data
# * Show the total number of HR employees

# %%
df_hr = df[df['role'].str.contains('HR')]
print(df_hr)
total_employee = df_hr.shape[0]
print("Total HR Employees: ", total_employee)
# Out:
#     emp_id  emp_age  emp_salary          role
# 0      101       54       51725    HR Manager
# 5      106       37       58915    HR Manager
# 9      110       38       90494  HR Executive
# 24     125       53       60584  HR Executive
# 27     128       21       71888  HR Executive
# 38     139       27       52013    HR Manager
# 42     143       47       55523  HR Executive
# 44     145       22       90794  HR Executive
# 45     146       52       41061    HR Manager
# Total HR Employees:  9

# %% [markdown]
# ### Q9.
# Sort the DataFrame by:
# * emp_age (ascending)
# * and then by emp_salary (descending)
#
#
# Display the top 5 employees after sorting, including:
#
# * emp_id
# * role
# * emp_salary

# %%
df_sort = df.sort_values(['emp_age', 'emp_salary'], ascending=[True, False])
df_display = df_sort[['emp_id', 'role', 'emp_salary']]
df_display.head()
# Out:
#     emp_id                role  emp_salary
# 30     131     Sales Executive       82550
# 18     119  Software Developer       63187
# 41     142    Digital Marketer       59500
# 2      103  Operations Manager       35452
# 36     137     Sales Executive       94427

# %% [markdown]
# ### Q10.
# Using .loc:
# * Increase salary by 12% for "Software Developer" and "Backend Developer"
# * Increase salary by 5% for all other roles
#
#
# Then:
# * Print the dataframe that includes role , previous_salary , new_salary , increase_of_salary

# %%
roles = ['Software Developer', 'Backend Developer']
df['emp_salary'] = df['emp_salary'].astype(float)
df['previous_salary'] = df['emp_salary']

df['new_salary'] = np.where( df['role'].isin(roles), df['previous_salary']*1.12, df['previous_salary']*1.05)
df['increase_of_salary'] = df['new_salary'] - df['previous_salary']
df_display = df[['role', 'previous_salary', 'new_salary', 'increase_of_salary']]
df_display
# Out:
#                    role  previous_salary  new_salary  increase_of_salary
# 0            HR Manager          51725.0    54311.25             2586.25
# 1            Accountant          38495.0    40419.75             1924.75
# 2    Operations Manager          35452.0    37224.60             1772.60
# 3      Digital Marketer          82295.0    86409.75             4114.75
# 4     Backend Developer          72187.0    80849.44             8662.44
# 5            HR Manager          58915.0    61860.75             2945.75
# 6     Backend Developer          76159.0    85298.08             9139.08
# 7       Sales Executive          92864.0    97507.20             4643.20
# 8       Sales Executive          76155.0    79962.75             3807.75
# 9          HR Executive          90494.0    95018.70             4524.70
# 10    Backend Developer          68641.0    76877.92             8236.92
# 11  Marketing Executive          48079.0    50482.95             2403.95
# ...
