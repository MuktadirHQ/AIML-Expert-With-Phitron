# %%
# Class Attribute.

class ClassName:
    att = "None"

instance_1 = ClassName()
instance_1.att = "SOme"
print(instance_1.att)

instance_2 = ClassName()
print(instance_2.att)
# Out:
# SOme
# None

# %%
# Instance Attribute.

class Phone:

    category = "Electronics"

    def __init__(self, model, battery, camera):
        self.model = model
        self.battery = battery
        self.camera = camera


apple = Phone("iphone-17", 4500, "50px")
samsung = Phone("Galaxy S25 Ultra", 6000, "120px")
print(samsung.model)
# Out:
# Galaxy S25 Ultra

# %%
# Methods.

class Phone:

    category = "Electronics"

    def __init__(self, model, battery, camera, battery_percentage=100):
        self.model = model
        self.battery = battery
        self.camera = camera
        self.battery_percentage = battery_percentage

    def charge(self, hour):
        print(f"charge completed by {hour} hour")

    def capture(self, photo):

        if (self.battery_percentage <= 0):
            print("No Charge")
        else:
            self.battery_percentage -= photo
            print("Photo Captured")


motorola = Phone("Model_X", 5000, "100px")
motorola.capture(10)
print(motorola.battery_percentage)
# Out:
# Photo Captured
# 90

# %%
# Inheritance.

class Smartphone(Phone):
    def __init__(self, model, battery, camera, processor):
        super().__init__(model, battery, camera)

        self.processor = processor

pro = Smartphone("XX", 5000, "100px", "Snapdragon")
print(pro.model)
print(pro.battery)
pro.charge(1)
# Out:
# XX
# 5000
# charge completed by 1 hour

# %%
# Multiple Inheritance.

class Cooling_Mechanism:
    def __init__(self, cooling_method):
        self.cooling_method = cooling_method

    def cooling_on(self):
        print(f"cooling method is {self.cooling_method}")




class SmartPhoneWithCooling(Phone, Cooling_Mechanism):
    def __init__(self, model, battery, camera, processor, cooling_method):
        Phone.__init__(self, model, battery, camera, processor)
        Cooling_Mechanism.__init__(self, cooling_method)



pro_cooling = SmartPhoneWithCooling("XX X", 5000, "100px", "Snapdragon", "Water")
pro_cooling.cooling_on()
pro.charge(21)
# Out:
# cooling method is Water
# charge completed by 21 hour

# %%
# Polymorphism.

class Camera:
    def __init__(self, name):
        self.name = name

    def capture(self):
        print("Photo Captured")


class Smart_Phone(Camera):
    def __init__(self, name, resulation):
        super().__init__(name)
        self.resulation = resulation

    def capture(self): # Method overriding
        print("Photo is captured by a Phone")

class DSLR(Camera):
    def __init__(self, name, resulation):
        super().__init__(name)
        self.resulation = resulation

    def capture(self): # Method overriding
        print("Photo is captured by a DSLR")

class Drone(Camera):
    def __init__(self, name, resulation):
        super().__init__(name)
        self.resulation = resulation

    def capture(self): # Method overriding
        print("Photo is captured by a Drone")



phone = Smart_Phone("17", 30)
dslr = DSLR("SONY", 200)
drone = Drone("DJI", 100)

phone.capture()
dslr.capture()
drone.capture()
# Out:
# Photo is captured by a Phone
# Photo is captured by a DSLR
# Photo is captured by a Drone

# %%
# Encapsulation.

class Mobile:
    def __init__(self, name, model, imei):
        self.__name = name
        self.model = model
        self.__imei = imei  # Private

    def charge(self):
        print("Phone is charging")

    def get_imei(self):
        return self.__imei


    def name_getter(self):
        return self.__name
    def name_setter(self, name):
        self.__name = name

iphone = Mobile("iphone", "17", 7618741667)
print(iphone.model)
print(iphone.name_getter())
iphone.name_setter("Iphone_5s")
print(iphone.name_getter())
print(iphone.get_imei())

print(iphone.imei)
# Out:
# 17
# iphone
# Iphone_5s
# 7618741667
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3151/1567606619.py in <cell line: 0>()
#      26 print(iphone.get_imei())
#      27
# ---> 28 print(iphone.imei)
#
# AttributeError: 'Mobile' object has no attribute 'imei'

# %%
# Abstraction.

from abc import ABC, abstractmethod

class Telephone(ABC):

    @abstractmethod
    def make_call(self):
        print("Making a Call")


class SPhone(Telephone):
    def make_call(self):
        print("Making a Call using SPhone")


class Iphone(Telephone):
    def make_call(self):
        print("Making a Call using Iphone")



ip = Iphone()
ip.make_call()
# Out:
# Making a Call using Iphone
